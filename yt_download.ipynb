# %%
pip install yt-dlp
# Out:
#   Cell In[1], line 1
#     pip install yt-dlp
#         ^
# SyntaxError: invalid syntax

# %%
yt-dlp -f "bestvideo[height<=480]+bestaudio/best" -o "%(title)s.%(ext)s" <https://www.youtube.com/watch?v=qZQIpZXmJv0&list=PLb2aaNHUy_gGNtS2Iig4M8ZqhMV9QaMti&index=1>
# Out:
#   Cell In[2], line 1
#     yt-dlp -f "bestvideo[height<=480]+bestaudio/best" -o "%(title)s.%(ext)s" <https://www.youtube.com/watch?v=qZQIpZXmJv0&list=PLb2aaNHUy_gGNtS2Iig4M8ZqhMV9QaMti&index=1>
#               ^
# SyntaxError: invalid syntax

# %%
pip install yt-dlp
# Out:
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
# ...

# %%
# yt-dlp -f "bestvideo[height<=480]+bestaudio/best" -o "%(playlist_index)s - %(title)s.%(ext)s" "https://www.youtube.com/playlist?list=PLb2aaNHUy_gGNtS2Iig4M8ZqhMV9QaMti"
# Out:
#   Cell In[5], line 1
#     yt-dlp -f "bestvideo[height<=480]+bestaudio/best" -o "%(playlist_index)s - %(title)s.%(ext)s" "https://www.youtube.com/playlist?list=PLb2aaNHUy_gGNtS2Iig4M8ZqhMV9QaMti"
#               ^
# SyntaxError: invalid syntax
